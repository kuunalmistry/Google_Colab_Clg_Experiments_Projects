# %% [markdown]
# <a href="https://colab.research.google.com/github/kuunalmistry/Google_Colab_Clg_Experiments_Projects/blob/main/YOLO_Practical_EmergingTech_KuunalMistry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
 Aim: Write a program in .py/.java to implement q-learning by considering the environment including the
number of stages or states ,actions ,action, goal state and q-table
"""
# Out:
# '\n Aim: Write a program in .py/.java to implement q-learning by considering the environment including the\nnumber of stages or states ,actions ,action, goal state and q-table\n'

# %%
""" State represents a position ina 4x4 grid and action represents movements in four directions """
# Out:
# ' State represents a position ina 4x4 grid and action represents movements in four directions '

# %%
"""
 Consider n_states = 16
goal_states = 15
n_actions = 4
 """
# Out:
# '\n Consider n_states = 16\ngoal_states = 15\nn_actions = 4\n '

# %%
from ultralytics import YOLO
from PIL import Image

model = YOLO("yolo11n.pt")

results = model("/content/IMG_4284.png")

for result in results:
    result.show()

    for box in result.boxes:
        class_id = int(box.cls[0])
        confidence = float(box.conf[0])
        class_name = model.names[class_id]

        print(
            f"Detected: {class_name}, "
            f"Confidence: {confidence:.2f}, "
            f"BoundingBox: {box.xyxy[0].tolist()}"
        )

    result.save(filename="output.jpg")

print("Object detection completed successfully.")
# Out:
# image 1/1 /content/IMG_4284.png: 320x640 7 cars, 1 truck, 171.7ms
# Speed: 2.4ms preprocess, 171.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=1200x550>
# Detected: car, Confidence: 0.88, BoundingBox: [649.5490112304688, 315.592041015625, 790.1009521484375, 416.1588134765625]
# Detected: car, Confidence: 0.75, BoundingBox: [1116.752197265625, 312.6462707519531, 1187.9229736328125, 367.0546875]
# Detected: car, Confidence: 0.70, BoundingBox: [1007.0433959960938, 310.8060607910156, 1062.4232177734375, 357.7344970703125]
# Detected: car, Confidence: 0.53, BoundingBox: [283.26202392578125, 294.5859680175781, 527.7440185546875, 489.6351013183594]
# Detected: car, Confidence: 0.52, BoundingBox: [804.149169921875, 306.1791076660156, 912.7483520507812, 394.60394287109375]
# Detected: truck, Confidence: 0.50, BoundingBox: [934.157470703125, 280.6239929199219, 1010.234130859375, 367.3941345214844]
# ...
