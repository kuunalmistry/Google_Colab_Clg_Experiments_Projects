# %% [markdown]
# <a href="https://colab.research.google.com/github/kuunalmistry/Google_Colab_Clg_Experiments_Projects/blob/main/Histogram_processing_Kuunal_Mistry_2410130.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
img1=np.arange(8,dtype=np.uint8).reshape(2,4)

# %%
img1
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 6, 7]], dtype=uint8)

# %%
plt.imshow(img1,cmap="gray")

# %%
hist1 = cv2.calcHist([img1],[0],None,[7],[0,7])

# %%
plt.plot(hist1)
plt.xlabel("pixel value")
plt.ylabel("frequency")
plt.show()

# %%
img2=np.random.randint(0,7,size=(200,200),dtype=np.uint8)

# %%
plt.imshow(img2,cmap="gray")

# %%
img2
# Out:
# array([[1, 5, 4, ..., 6, 5, 6],
#        [6, 1, 4, ..., 4, 5, 6],
#        [3, 4, 5, ..., 6, 2, 3],
#        ...,
#        [2, 1, 2, ..., 0, 3, 5],
#        [4, 0, 3, ..., 0, 1, 6],
#        [6, 0, 6, ..., 5, 2, 0]], dtype=uint8)

# %%
hist2=cv2.calcHist([img2],[0],None,[7],[0,7])

# %%
plt.plot(hist2)
plt.xlabel("pixel value")
plt.ylabel("frequency")
plt.show()

# %%
img3=cv2.imread("/content/Cars.jpeg",0)
# To change the color of the graph, use the 'color' parameter in plt.plot().
# For example: plt.plot(hist3, color='red'). You would typically apply this in cell g3UuhTgfF0kF.

# %%
img3
# Out:
# array([[182, 182, 182, ..., 183, 183, 183],
#        [182, 182, 182, ..., 183, 183, 183],
#        [182, 182, 182, ..., 185, 185, 185],
#        ...,
#        [106, 106, 106, ..., 108, 107, 107],
#        [109, 102,  94, ..., 112, 108, 106],
#        [ 90,  89,  88, ..., 138, 134, 132]], dtype=uint8)

# %%
min=np.min(img3)
max=np.max(img3)

# %%
min
# Out:
# np.uint8(0)

# %%
max
# Out:
# np.uint8(255)

# %%
img3.shape
# Out:
# (720, 1280)

# %%
hist3=cv2.calcHist([img3],[0],None,[256],[0,256])

# %%
plt.plot(hist3)
plt.xlabel("pixel value")
plt.ylabel("frequency")
plt.show()
#Brighter Image

# %%
img4=cv2.imread("/content/Cars.jpeg")

# %%
img4
# Out:
# array([[[237, 186, 153],
#         [237, 186, 153],
#         [239, 186, 153],
#         ...,
#         [227, 186, 161],
#         [227, 186, 161],
#         [227, 186, 161]],
#
#        [[237, 186, 153],
#         [237, 186, 153],
#         [239, 186, 153],
#         ...,
#         [227, 186, 161],
#         [227, 186, 161],
#         [227, 186, 161]],
#
#        [[237, 187, 151],
#         [237, 187, 151],
#         [239, 187, 151],
#         ...,
#         [229, 188, 163],
#         [229, 188, 163],
#         [229, 188, 163]],
#
#        ...,
#
#        [[ 85,  84, 156],
#         [ 85,  84, 156],
#         [ 85,  85, 155],
#         ...,
#         [ 65, 100, 140],
#         [ 64, 100, 138],
#         [ 64, 100, 138]],
#
#        [[ 90,  87, 159],
#         [ 83,  80, 152],
#         [ 75,  73, 143],
#         ...,
#         [ 54, 105, 148],
#         [ 50, 101, 144],
#         [ 48,  99, 142]],
#
#        [[ 71,  68, 140],
#         [ 70,  67, 139],
#         [ 69,  67, 137],
# ...

# %%
cv2_imshow(img4)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
img4.shape
# Out:
# (720, 1280, 3)

# %%
min=np.min(img4)
max=np.max(img4)

# %%
min
# Out:
# np.uint8(0)

# %%
max
# Out:
# np.uint8(255)

# %%
hist4=cv2.calcHist([img4],[0],None,[256],[0,256])

# %%
plt.plot(hist4)
plt.title("Blue Colour")
plt.xlabel("pixel value")
plt.ylabel("frequency")
plt.show()

# %%
hist5=cv2.calcHist([img4],[1],None,[256],[0,256])

# %%
plt.plot(hist5)
plt.title("Green Colour")
plt.xlabel("pixel value")
plt.ylabel("frequency")
plt.show()

# %%
hist6=cv2.calcHist([img4],[2],None,[256],[0,256])

# %%
plt.plot(hist6)
plt.title("Red Colour")
plt.xlabel("pixel value")
plt.ylabel("frequency")
plt.show()

# %%
img3.shape
# Out:
# (720, 1280)

# %%
mask=np.zeros(img3.shape,np.uint8)

# %%
mask[100:200,100:200]=255

# %%
cv2_imshow(mask)
# Out:
# <PIL.Image.Image image mode=L size=1280x720>

# %%
hist7=cv2.calcHist([img3],[0],mask,[256],[0,256])

# %%
plt.plot(hist7)
plt.xlabel("pixel value")
plt.ylabel("frequency")
plt.show()

# %%
plt.subplot(2,2,1)
plt.plot(hist3)
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")
plt.title("Original Image")

plt.subplot(2,2,2)
plt.plot(hist7)
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")
plt.title("Masked Image")
# Out:
# Text(0.5, 1.0, 'Masked Image')
